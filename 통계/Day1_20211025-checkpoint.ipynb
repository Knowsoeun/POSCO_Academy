# %%
import pandas as pd
import numpy as np

#데이터 시각화 패키지
import matplotlib
import matplotlib.pyplot as plt

#데이터 시각화(추세 등) 패키지
import seaborn as sns

#통계 분석 패키지
from scipy import stats
import scipy.stats

#jupyter notebook 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline

# %%
#matplotlib 패키지 한글 깨짐 처리 시작
#한글 폰트(말은 고딕) 적용 : 윈도우,

# %%
#mycars 데이터 가져오기

ds_mycars = pd.read_csv("/home/piai/mycars.csv", engine = "python")
#E:data/statistics_python/mycars.csv
ds_mycars.head()
# Out:
#   manufacturer model  displacement  year  cylinder automatic driving  mpg  \
# 0         audi    a4           1.8  1999         4      auto       f   18
# 1         audi    a4           1.8  1999         4    manual       f   21
# 2         audi    a4           2.0  2008         4    manual       f   20
# 3         audi    a4           2.0  2008         4      auto       f   21
# 4         audi    a4           2.8  1999         6      auto       f   16
#
#    highway_mileage fuel    class
# 0               29    p  compact
# 1               29    p  compact
# 2               31    p  compact
# 3               30    p  compact
# 4               26    p  compact

# %%
#1. 시내에서 연비(mpg) 통계치 : 기술통계
ds_mycars.describe()
# Out:
#        displacement         year    cylinder         mpg  highway_mileage
# count    234.000000   234.000000  234.000000  234.000000       234.000000
# mean       3.471795  2003.500000    5.888889   16.858974        23.440171
# std        1.291959     4.509646    1.611534    4.255946         5.954643
# min        1.600000  1999.000000    4.000000    9.000000        12.000000
# 25%        2.400000  1999.000000    4.000000   14.000000        18.000000
# 50%        3.300000  2003.500000    6.000000   17.000000        24.000000
# 75%        4.600000  2008.000000    8.000000   19.000000        27.000000
# max        7.000000  2008.000000    8.000000   35.000000        44.000000

# %%
#2. 자동차 모델별, mpg별 통계치 : 모델별 mpg 데이터 subset
df = ds_mycars[['model','mpg']]
df.head()
# Out:
#   model  mpg
# 0    a4   18
# 1    a4   21
# 2    a4   20
# 3    a4   21
# 4    a4   16

# %%
# 자동차 모델 별, mpg 기술통계량
df.groupby('model').describe()
# Out:
#                          mpg                                                 \
#                        count       mean       std   min    25%   50%    75%
# model
# 4runner 4wd              6.0  15.166667  0.752773  14.0  15.00  15.0  15.75
# a4                       7.0  18.857143  1.864454  16.0  18.00  18.0  20.50
# a4 quattro               8.0  17.125000  1.807722  15.0  15.75  17.0  18.25
# a6 quattro               3.0  16.000000  1.000000  15.0  15.50  16.0  16.50
# altima                   6.0  20.666667  1.966384  19.0  19.00  20.0  22.50
# c1500 suburban 2wd       5.0  12.800000  1.303840  11.0  12.00  13.0  14.00
# camry                    7.0  19.857143  1.463850  18.0  18.50  21.0  21.00
# camry solara             7.0  19.857143  1.772811  18.0  18.00  21.0  21.00
# caravan 2wd             11.0  15.818182  1.834022  11.0  15.50  16.0  17.00
# civic                    9.0  24.444444  1.943651  21.0  24.00  24.0  25.00
# ...

# %%
##존나 위에서부터 밀려서 못함ㅅㅄㅄㅄㅂ

#Column의 name(좌측상단 이름)생성
count_data.columns.name = 'Flaws'
count_data

#Period 변수 Count : value_count. 순서대로 정렬 : sort_index
count2 = df['Period'].value_counts().sort_index()
count2

#CumCnt(cumulative counts) 계산 : cumsum
cumcnt2 = np.cumsum(count2)
cumcnt2

#Percent 계산 : 직접
percent2 = count2/sum(count2) * 100
percent2

#CumPct(cumulative percetns) 계산 : cumsum
cumpct2 = np.cumsum(percent2)
cumpct2

#DataFrame으로 취합
#count_data2 =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-b2dc9804048d> in <module>
#       2
#       3 #Column의 name(좌측상단 이름)생성
# ----> 4 count_data.columns.name = 'Flaws'
#       5 count_data
#       6
#
# NameError: name 'count_data' is not defined

# %% [markdown]
# ### [실습1.]실습통계 분석

# %%
import pandas as pd
import numpy as np

#데이터 시각화 패키지
import matplotlib
import matplotlib.pyplot as plt

#데이터 시각화(추세 등) 패키지
import seaborn as sns

#통계 분석 패키지
from scipy import stats
import scipy.stats

#jupyter notebook 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline

#mycars 데이터 가져오기

ds_mycars = pd.read_csv("/home/piai/mycars.csv", engine = "python")

# %%
#1. 시내에서 연비(mpg) 통계치 : 기술통계량
ds_mycars.describe()
# Out:
#        displacement         year    cylinder         mpg  highway_mileage
# count    234.000000   234.000000  234.000000  234.000000       234.000000
# mean       3.471795  2003.500000    5.888889   16.858974        23.440171
# std        1.291959     4.509646    1.611534    4.255946         5.954643
# min        1.600000  1999.000000    4.000000    9.000000        12.000000
# 25%        2.400000  1999.000000    4.000000   14.000000        18.000000
# 50%        3.300000  2003.500000    6.000000   17.000000        24.000000
# 75%        4.600000  2008.000000    8.000000   19.000000        27.000000
# max        7.000000  2008.000000    8.000000   35.000000        44.000000

# %%
# 시내에서 연비(mpg) 통계치 
df = ds_mycars[['automatic','mpg']]

# %%
# 시내에서 연비(mpg) 통계치 
df.groupby('automatic').describe()
# Out:
#              mpg
#            count       mean       std  min   25%   50%   75%   max
# automatic
# auto       157.0  15.968153  3.848777  9.0  13.0  16.0  18.0  29.0
# manual      77.0  18.675325  4.488118  9.0  15.0  18.0  21.0  35.0

# %%
# 고속도로에서 연비(mpg) 통계치 

df2 = ds_mycars[['automatic','highway_mileage']]

# %%
# 시내에서 연비(mpg) 통계치 
df2.groupby('automatic').describe()
# Out:
#           highway_mileage
#                     count       mean       std   min   25%   50%   75%   max
# automatic
# auto                157.0  22.292994  5.623054  12.0  17.0  22.0  26.0  41.0
# manual               77.0  25.779221  5.961772  12.0  23.0  26.0  29.0  44.0
