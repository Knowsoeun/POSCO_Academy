# %%
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sml
import statsmodels.formula.api as smf
import statsmodels.api as sm
import scipy.stats
from scipy import stats
from scipy.stats import shapiro
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.anova import anova_lm
from statsmodels.tools.eval_measures import rmse
from statsmodels.api import qqplot, add_constant
from statsmodels.api import qqplot, add_constant
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from statsmodels.api import Logit
import graphviz
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

from sklearn.decomposition import PCA
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
plt.rcParams['font.family'] = 'Noto Sans CJK JP'
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score
# df_raw = pd.read_csv("", encoding = 'cp949')
# df_raw.head()
#plt.rcParams["font.family"] = "NanumGothic"
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Malgun Gothic"
path = 'C:/Program Files/Graphviz/bin'
matplotlib.rc('font',family = 'Malgun Gothic')

# %%
matplotlib.rc('font', family = 'Noto Sans CJK JP')
plt.rcParams['font.family'] = 'Noto Sans CJK JP'

# %% [markdown]
# ## Step1. 변수 별 데이터 분포 확인

# %% [markdown]
# ### ■ jeju_member

# %% [markdown]
# ### Step1-1.  jeju_member 데이터 불러오기

# %%
df_raw = pd.read_csv("C:/Users/소은/Desktop/A2_유통 (1)/jeju_member.csv", engine='python', encoding='utf-8')
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6013 entries, ('C102666', '1976-11-08', '남', 44, '40대', '일반', '3Gold', '2014-10-07', nan, 63, '매장', 'Y', 'Y', 'Y', 'Y', '690-170', '제주시', '연동', nan) to ('C708358', '1972-06-18', '여', 48, '40대', '일반', '3Gold', '2019-12-23', nan, 1, '기타', 'Y', 'Y', 'N', 'Y', '697-100', '서귀포시', '서호동', nan)
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  6013 non-null   object
# dtypes: object(1)
# memory usage: 308.5+ KB

# %% [markdown]
# ### ■ jeju_sales

# %% [markdown]
# ### Step1-4.  jeju_sales 데이터 불러오기

# %%
df_raw1 = pd.read_csv("C:/Users/소은/Desktop/A2_유통 (1)/jeju_sales.csv", parse_dates=['purchase_date','supply_date'])
df_raw1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273322 entries, 0 to 273321
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customer_id         273322 non-null  object
#  1   purchase_id         273322 non-null  object
#  2   store_id            273322 non-null  object
#  3   purchase_yearmonth  273322 non-null  object
#  4   purchase_weekday    273322 non-null  object
#  5   purchase_hour       273322 non-null  int64
#  6   purchase_date       273322 non-null  datetime64[ns]
#  7   purchase_time       273322 non-null  object
#  8   supply_date         273322 non-null  datetime64[ns]
#  9   item_id             273322 non-null  object
#  10  item_g_l            273322 non-null  object
#  11  item_g_m            273322 non-null  object
#  12  item_g_s            273322 non-null  object
#  13  item_name           273322 non-null  object
#  14  purchase_cnt        273322 non-null  int64
#  15  unit_cost           273322 non-null  int64
#  16  purchase_amt        273322 non-null  int64
# dtypes: datetime64[ns](2), int64(4), object(11)
# memory usage: 35.4+ MB

# %% [markdown]
# ## Step2. CSV 파일 병합

# %% [markdown]
# #### [파일 병합 방법]
# ##### 'customer_id'를 조인키로 사용해서 jeju_members.csv와 jeju_sales.csv 파일 병합
# ##### WHY? 2개 파일 병합 후 여러 변수간 상관관계를 파악하기 위해서

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
import json

pd.options.display.float_format = '{:,.2f}'.format
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-21d4226e55ae> in <module>
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 import squarify
#       7 import json
#       8
#
# ModuleNotFoundError: No module named 'squarify'

# %%
import geopandas as gpd
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer
from bokeh.models import HoverTool
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-9d007a0101d0> in <module>
# ----> 1 import geopandas as gpd
#       2 from bokeh.io import output_notebook, show, output_file
#       3 from bokeh.plotting import figure
#       4 from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
#       5 from bokeh.palettes import brewer
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
merge_df = pd.merge(df_raw, df_raw1, on = 'customer_id')
merge_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f4e27081cb33> in <module>
# ----> 1 merge_df = pd.merge(df_raw, df_raw1, on = 'customer_id')
#       2 merge_df.head()
#
# NameError: name 'df_raw' is not defined

# %%
original = pd.DataFrame()
original['mean'] = merge_df.groupby(['customer_grade'])['purchase_amt'].agg('mean')
original['count'] = merge_df['customer_grade'].value_counts()
original
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-76825e8e6709> in <module>
#       1 original = pd.DataFrame()
# ----> 2 original['mean'] = merge_df.groupby(['customer_grade'])['purchase_amt'].agg('mean')
#       3 original['count'] = merge_df['customer_grade'].value_counts()
#       4 original
#
# NameError: name 'merge_df' is not defined

# %%
import datetime as dt
NOW = dt.datetime(2019,12,30)
# NOW는 데이터 마지막 날짜 + 1 한 값

# %%
# customer_id로 그룹화
# rfm.rename: 새로우 테이블을 만듬
rfm = merge_df.groupby('customer_id').agg({
                                        'purchase_date' : lambda x: (NOW - x.max()).days,
                                         'purchase_id'  : lambda x: len(x),
                                         'purchase_amt' : lambda x : sum(x)
                                       })
rfm.rename(columns = {'purchase_date': 'Recency',
                         'purchase_id': 'Frequency',
                         'purchase_amt': 'MonetaryValue'}, inplace = True)

rfm.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-760746f2e01f> in <module>
#       1 # customer_id로 그룹화
#       2 # rfm.rename: 새로우 테이블을 만듬
# ----> 3 rfm = merge_df.groupby('customer_id').agg({
#       4                                         'purchase_date' : lambda x: (NOW - x.max()).days,
#       5                                          'purchase_id'  : lambda x: len(x),
#
# NameError: name 'merge_df' is not defined

# %% [markdown]
# #### ● 사분위수로 나누어 Recency, Frequency 및 MonetaryValue 값을 개별적으로 부여.
# #### ● 세 가지 등급을 결합하여 RFM Segment를 얻음.
# #### ● 세 가지 등급을 합산하여 RFM 점수 획득.
# #### ● RFM Segment를 요약해서 결과 분석.
#
# #### ●우리 유통는 고객이 '더 자주 방문'하고 '더 많은 비용'을 지출하기를 원하기 때문에 "Frequency"와 "Monetary"를 높게 평가했음.

# %%
# qcut 함수를 사용하여 RFM 그룹, 라벨 및 사분위수 계산
r_labels = range(4, 0, -1)
f_labels = range(1, 5)
m_labels = range(1, 5)

# 4개의 동일한 백분위수 그룹에 label 할당
r_groups = pd.qcut(rfm['Recency'], q = 4, labels = r_labels)
# 4개의 동일한 백분위수 그룹에 label 할당
f_groups = pd.qcut(rfm['Frequency'], q = 4, labels = f_labels)
# 4개의 동일한 백분위수 그룹에 label 할당
m_groups = pd.qcut(rfm['MonetaryValue'], q = 4, labels = m_labels)

# %%
print(r_groups[:5])
print(f_groups[:5])
print(m_groups[:5])
# Out:
# customer_id
# C118113    1
# C118291    4
# C118294    3
# C118295    2
# C118298    4
# Name: Recency, dtype: category
# Categories (4, int64): [4 < 3 < 2 < 1]
# customer_id
# C118113    2
# C118291    4
# C118294    3
# C118295    2
# C118298    4
# Name: Frequency, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]
# customer_id
# C118113    2
# C118291    4
# C118294    3
# C118295    2
# C118298    3
# Name: MonetaryValue, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %%
# 원래 RFM에 새 Column 추가
rfm = rfm.assign(R = r_groups.values, F = f_groups.values, M = m_groups.values)
rfm.head(20)
# Out:
#              Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# customer_id
# C118113          403          9          99500  1  2  2         122
# C118291            0        164        1062850  4  4  4         444
# C118294           43         26         165000  3  3  3         333
# C118295          123         16         107600  2  2  2         222
# C118298           13        144         526090  4  4  3         443
# C118299          321          1           7600  1  1  1         111
# C118300           42         10         184800  3  2  3         323
# C118476           30         97         666400  3  3  4         334
# C118477           88         82         660960  2  3  4         234
# C118530           77         52         256350  2  3  3         233
# C118590           34         93         535750  3  3  4         334
# C118721          555          5          14100  1  1  1         111
# C118868          271          2           5500  1  1  1         111
# C119301           15        231         702030  3  4  4         344
# C119412          480          4          10700  1  1  1         111
# C119415          139         40         260200  2  3  3         233
# C119580           13         51         254500  4  3  3         433
# C119611           82         37         376150  2  3  3         233
# C121157           15        211        1060970  3  4  4         344
# C121175            0        157         923950  4  4  4         444
#
#              RFM_Score  RFM_Level  purchase_amt
# customer_id
# C118113           6.00      3Gold     22,000.00
# C118291          15.00     1Royal     39,000.00
# C118294           9.00  2Platinum     20,000.00
# C118295           8.00      3Gold     16,900.00
# C118298          13.00  2Platinum     15,600.00
# C118299           3.00    4Silver      7,600.00
# C118300           8.00      3Gold     46,500.00
# C118476          12.00  2Platinum     98,000.00
# C118477          11.00  2Platinum    127,000.00
# C118530          11.00  2Platinum     18,800.00
# C118590          12.00  2Platinum     17,200.00
# C118721           3.00    4Silver      5,900.00
# C118868           4.00    4Silver      4,200.00
# C119301          13.00  2Platinum      8,400.00
# C119412           3.00    4Silver      3,750.00
# C119415           9.00  2Platinum     45,900.00
# C119580          12.00  2Platinum     25,100.00
# C119611          10.00  2Platinum     35,000.00
# C121157          14.00  2Platinum     35,000.00
# C121175          15.00     1Royal     30,700.00

# %%
# 세 가지 등급을 결합하여 RFM Segment를 얻음.
rfm['RFM_segment'] = rfm.apply(lambda x: (str(x['R']) + str(x['F']) + str(x['M'])), axis=1)
rfm.head(20)
# Out:
#              Recency  Frequency  MonetaryValue  R  F  M RFM_segment  \
# customer_id
# C118113          403          9          99500  1  2  2         122
# C118291            0        164        1062850  4  4  4         444
# C118294           43         26         165000  3  3  3         333
# C118295          123         16         107600  2  2  2         222
# C118298           13        144         526090  4  4  3         443
# C118299          321          1           7600  1  1  1         111
# C118300           42         10         184800  3  2  3         323
# C118476           30         97         666400  3  3  4         334
# C118477           88         82         660960  2  3  4         234
# C118530           77         52         256350  2  3  3         233
# C118590           34         93         535750  3  3  4         334
# C118721          555          5          14100  1  1  1         111
# C118868          271          2           5500  1  1  1         111
# C119301           15        231         702030  3  4  4         344
# C119412          480          4          10700  1  1  1         111
# C119415          139         40         260200  2  3  3         233
# C119580           13         51         254500  4  3  3         433
# C119611           82         37         376150  2  3  3         233
# C121157           15        211        1060970  3  4  4         344
# C121175            0        157         923950  4  4  4         444
#
#              RFM_Score  RFM_Level  purchase_amt
# customer_id
# C118113           6.00      3Gold     22,000.00
# C118291          15.00     1Royal     39,000.00
# C118294           9.00  2Platinum     20,000.00
# C118295           8.00      3Gold     16,900.00
# C118298          13.00  2Platinum     15,600.00
# C118299           3.00    4Silver      7,600.00
# C118300           8.00      3Gold     46,500.00
# C118476          12.00  2Platinum     98,000.00
# C118477          11.00  2Platinum    127,000.00
# C118530          11.00  2Platinum     18,800.00
# C118590          12.00  2Platinum     17,200.00
# C118721           3.00    4Silver      5,900.00
# C118868           4.00    4Silver      4,200.00
# C119301          13.00  2Platinum      8,400.00
# C119412           3.00    4Silver      3,750.00
# C119415           9.00  2Platinum     45,900.00
# C119580          12.00  2Platinum     25,100.00
# C119611          10.00  2Platinum     35,000.00
# C121157          14.00  2Platinum     35,000.00
# C121175          15.00     1Royal     30,700.00

# %%
# 데이터 타입 확인
rfm.dtypes
# Out:
# Recency             int64
# Frequency           int64
# MonetaryValue       int64
# R                category
# F                category
# M                category
# RFM_segment        object
# RFM_Score         float64
# RFM_Level          object
# purchase_amt      float64
# dtype: object

# %%
# R, F, M, RFM_Score 4개 Column 데이터 타입 float로 변경.
rfm = rfm.astype({'R':'float'})
rfm = rfm.astype({'F':'float'})
rfm = rfm.astype({'M':'float'})
# rfm = rfm.astype({'RFM_Score':'float'})

# %%
# 데이터 타입 변경 확인.
rfm.dtypes
# Out:
# Recency            int64
# Frequency          int64
# MonetaryValue      int64
# R                float64
# F                float64
# M                float64
# RFM_segment       object
# RFM_Score        float64
# RFM_Level         object
# purchase_amt     float64
# dtype: object

# %%
# 세 가지 등급을 합산하여 RFM 점수를 얻음.
rfm['RFM_Score'] = rfm['R'] + rfm['F'] + rfm['M']
rfm['RFM_Score'] = rfm['RFM_Score'].apply(lambda x : float(x))
rfm.head(100)
# Out:
#              Recency  Frequency  MonetaryValue    R    F    M RFM_segment  \
# customer_id
# C118113          403          9          99500 1.00 2.00 2.00         122
# C118291            0        164        1062850 4.00 4.00 4.00         444
# C118294           43         26         165000 3.00 3.00 3.00         333
# C118295          123         16         107600 2.00 2.00 2.00         222
# C118298           13        144         526090 4.00 4.00 3.00         443
# ...              ...        ...            ...  ...  ...  ...         ...
# C144698            4        160         794255 4.00 4.00 4.00         444
# C144750          128         55         237595 2.00 3.00 3.00         233
# C144963           91          8          62400 2.00 2.00 2.00         222
# C145749           20        132         919960 3.00 4.00 4.00         344
# C145862           17        224        1389620 3.00 4.00 4.00         344
#
#              RFM_Score  RFM_Level  purchase_amt
# customer_id
# C118113           5.00      3Gold     22,000.00
# C118291          12.00     1Royal     39,000.00
# C118294           9.00  2Platinum     20,000.00
# C118295           6.00      3Gold     16,900.00
# C118298          11.00  2Platinum     15,600.00
# ...                ...        ...           ...
# C144698          12.00     1Royal     45,900.00
# C144750           8.00      3Gold     14,915.00
# C144963           6.00      3Gold     16,900.00
# C145749          11.00  2Platinum     34,000.00
# C145862          11.00  2Platinum     30,800.00
#
# [100 rows x 10 columns]

# %%
rfm.describe()
# Out:
#        Recency  Frequency  MonetaryValue        R        F        M  \
# count 2,755.00   2,755.00       2,755.00 2,755.00 2,755.00 2,755.00
# mean    143.85      99.21     559,775.72     2.51     2.47     2.50
# std     179.12     207.58   1,593,178.33     1.13     1.14     1.12
# min       0.00       1.00       1,000.00     1.00     1.00     1.00
# 25%      14.00       7.00      37,250.00     2.00     1.00     1.50
# 50%      61.00      23.00     141,950.00     3.00     2.00     2.00
# 75%     214.00      97.00     533,250.00     4.00     3.00     3.50
# max     727.00   3,299.00  61,662,297.00     4.00     4.00     4.00
#
#        RFM_Score  purchase_amt
# count   2,755.00      2,754.00
# mean        7.48     29,754.72
# std         3.03     45,327.11
# min         3.00      1,000.00
# 25%         5.00      9,600.00
# 50%         7.00     17,000.00
# 75%        10.00     30,700.00
# max        12.00    588,000.00

# %%
# 중요도에 따라 rfm_level 함수를 정의하는 함수 생성.
# 사분위로 등급을 나눔
# 50%까지는 4Silver
# 50~75% 사이는 3Gold
# 75~99% 사이는 2Platinum
# 100% 즉, Max만 1Royal

def rfm_level(df):
    if df['RFM_Score'] >= 12:
        return '1Royal'
    elif ((df['RFM_Score'] >= 9) and (df['RFM_Score'] < 12)):
        return '2Platinum'
    elif ((df['RFM_Score'] >= 6) and (df['RFM_Score'] < 9)):
        return '3Gold'
    elif ((df['RFM_Score'] >= 3) and (df['RFM_Score'] < 6)):
        return '4Silver'
#     else:
#         return

# 새 변수 RFM_Level 생성
rfm['RFM_Level'] = rfm.apply(rfm_level, axis=1)
rfm.head(30)
# Out:
#              Recency  Frequency  MonetaryValue    R    F    M RFM_segment  \
# customer_id
# C118113          403          9          99500 1.00 2.00 2.00         122
# C118291            0        164        1062850 4.00 4.00 4.00         444
# C118294           43         26         165000 3.00 3.00 3.00         333
# C118295          123         16         107600 2.00 2.00 2.00         222
# C118298           13        144         526090 4.00 4.00 3.00         443
# C118299          321          1           7600 1.00 1.00 1.00         111
# C118300           42         10         184800 3.00 2.00 3.00         323
# C118476           30         97         666400 3.00 3.00 4.00         334
# C118477           88         82         660960 2.00 3.00 4.00         234
# C118530           77         52         256350 2.00 3.00 3.00         233
# C118590           34         93         535750 3.00 3.00 4.00         334
# C118721          555          5          14100 1.00 1.00 1.00         111
# C118868          271          2           5500 1.00 1.00 1.00         111
# C119301           15        231         702030 3.00 4.00 4.00         344
# C119412          480          4          10700 1.00 1.00 1.00         111
# C119415          139         40         260200 2.00 3.00 3.00         233
# C119580           13         51         254500 4.00 3.00 3.00         433
# C119611           82         37         376150 2.00 3.00 3.00         233
# C121157           15        211        1060970 3.00 4.00 4.00         344
# C121175            0        157         923950 4.00 4.00 4.00         444
# C121449            1        767        6188200 4.00 4.00 4.00         444
# C121524          493         33         233650 1.00 3.00 3.00         133
# C121819            0        249        1178500 4.00 4.00 4.00         444
# C122517            0        553        3101060 4.00 4.00 4.00         444
# C122866          663          3          30400 1.00 1.00 1.00         111
# C123728           70        229        1004940 2.00 4.00 4.00         244
# C123755            4        237        1669150 4.00 4.00 4.00         444
# C123900          367          1           9800 1.00 1.00 1.00         111
# C124489           72         22         118900 2.00 2.00 2.00         222
# C124588           18         74         251750 3.00 3.00 3.00         333
#
#              RFM_Score  RFM_Level  purchase_amt
# customer_id
# C118113           5.00    4Silver     22,000.00
# C118291          12.00     1Royal     39,000.00
# C118294           9.00  2Platinum     20,000.00
# C118295           6.00      3Gold     16,900.00
# C118298          11.00  2Platinum     15,600.00
# C118299           3.00    4Silver      7,600.00
# C118300           8.00      3Gold     46,500.00
# C118476          10.00  2Platinum     98,000.00
# C118477           9.00  2Platinum    127,000.00
# C118530           8.00      3Gold     18,800.00
# C118590          10.00  2Platinum     17,200.00
# C118721           3.00    4Silver      5,900.00
# C118868           3.00    4Silver      4,200.00
# C119301          11.00  2Platinum      8,400.00
# C119412           3.00    4Silver      3,750.00
# C119415           8.00      3Gold     45,900.00
# C119580          10.00  2Platinum     25,100.00
# C119611           8.00      3Gold     35,000.00
# C121157          11.00  2Platinum     35,000.00
# C121175          12.00     1Royal     30,700.00
# C121449          12.00     1Royal    468,000.00
# C121524           7.00      3Gold     16,800.00
# C121819          12.00     1Royal     30,700.00
# C122517          12.00     1Royal     52,000.00
# C122866           3.00    4Silver     18,800.00
# C123728          10.00  2Platinum     21,000.00
# C123755          12.00     1Royal     39,500.00
# C123900           3.00    4Silver      9,800.00
# C124489           6.00      3Gold     13,600.00
# C124588           9.00  2Platinum      8,900.00

# %%
rfm['RFM_Level'].value_counts().plot(kind = 'bar', figsize = (10, 5), color = 'skyblue')
plt.title('Customer Distribution Across Different RFM levels', fontsize = 15)
plt.xticks(rotation = 0)
plt.show()

# %%
merge1 = pd.read_excel('merge1.xlsx')
merge1
# Out:
#      customer_id  purchase_amt  purchase_cnt gender agegroup customer_grade
# 0        C118113         22000             2      여      40대          3Gold
# 1        C118291         39000             3      여      50대         1Royal
# 2        C118294         20000             5      여      40대      2Platinum
# 3        C118295         16900             1      여      50대          3Gold
# 4        C118298         15600             3      여      60대      2Platinum
# ...          ...           ...           ...    ...      ...            ...
# 2750     C704198          7750             5      여      30대      2Platinum
# 2751     C704239         15700             1      여      50대          3Gold
# 2752     C704271         14000             2      여      40대      2Platinum
# 2753     C704612         10800             4      여      50대          3Gold
# 2754     C705016         15700             1      여      40대      2Platinum
#
# [2755 rows x 6 columns]

# %%
sales = merge1[merge1['customer_id'] != 'C355132']

# %%
sales.set_index('customer_id', inplace = True)

# %%
rfm['purchase_amt'] = sales['purchase_amt']
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2755 entries, C118113 to C705016
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Recency        2755 non-null   int64
#  1   Frequency      2755 non-null   int64
#  2   MonetaryValue  2755 non-null   int64
#  3   R              2755 non-null   float64
#  4   F              2755 non-null   float64
#  5   M              2755 non-null   float64
#  6   RFM_segment    2755 non-null   object
#  7   RFM_Score      2755 non-null   float64
#  8   RFM_Level      2755 non-null   object
#  9   purchase_amt   2754 non-null   float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 236.8+ KB

# %%
RFM_total = pd.DataFrame()

RFM_total['level'] = rfm['RFM_Level']
RFM_total['price'] = rfm['purchase_amt']
RFM_total.count()
# Out:
# level    2755
# price    2754
# dtype: int64

# %% [markdown]
# # 회원분류 재분류 전 지표

# %%
change = pd.DataFrame()
change['mean'] = sales.groupby(['customer_grade'])['purchase_amt'].agg('mean').round(1)
change['count'] = sales['customer_grade'].value_counts()
change['price'] = change['mean'] * change['count']
change
# Out:
#                      mean  count         price
# customer_grade
# 1Royal         106,696.80     92  9,816,105.60
# 2Platinum       40,081.90    751 30,101,506.90
# 3Gold           24,365.50   1540 37,522,870.00
# 4Silver         12,140.20    371  4,504,014.20

# %%
change['price'].sum().round(1)
# Out:
# 81944496.7

# %% [markdown]
# # 회원등급 재분류 후의 지표

# %%
level_price = pd.DataFrame()
level_price['mean'] = RFM_total.groupby(['level'])['price'].agg('mean').round(1)
level_price['count'] = rfm['RFM_Level'].value_counts()
level_price['price'] = level_price['mean'] * level_price['count']
level_price
# Out:
#                mean  count         price
# level
# 1Royal    69,365.00    395 27,399,175.00
# 2Platinum 36,858.90    688 25,358,923.20
# 3Gold     24,271.30    783 19,004,427.90
# 4Silver   11,480.60    889 10,206,253.40

# %%
level_price['price'].sum().round(1)
# Out:
# 81968779.5

# %% [markdown]
# ## (매출 = 회원 수 x 객단가) 회원 재등급 전과 후 매출 차이

# %%
x = level_price['price'].sum().round(1) - change['price'].sum().round(1)
x.round()
# Out:
# 24283.0

# %% [markdown]
# ## K-means

# %%
merge_df['customer_id'] = '/' + merge_df['customer_id'].astype(str)

# %%
merge_df['customer_id'] = merge_df['customer_id'].str.extract('(\d+)', expand = False)

# %%
print(merge_df)
# Out:
#        customer_id  birth_date gender  age agegroup customer_type  \
# 0           118113  1975-08-18      여   45      40대            일반
# 1           118113  1975-08-18      여   45      40대            일반
# 2           118113  1975-08-18      여   45      40대            일반
# 3           118113  1975-08-18      여   45      40대            일반
# 4           118113  1975-08-18      여   45      40대            일반
# ...            ...         ...    ...  ...      ...           ...
# 273317      705016  1976-01-23      여   44      40대            일반
# 273318      705016  1976-01-23      여   44      40대            일반
# 273319      705016  1976-01-23      여   44      40대            일반
# 273320      705016  1976-01-23      여   44      40대            일반
# 273321      705016  1976-01-23      여   44      40대            일반
#
#        customer_grade  gaip_date taltoi_date  member_month  ... purchase_time  \
# 0               3Gold 2011-12-06         NaT            97  ...   :0:14:47:04
# 1               3Gold 2011-12-06         NaT            97  ...   :0:14:47:04
# 2               3Gold 2011-12-06         NaT            97  ...   :0:14:47:04
# 3               3Gold 2011-12-06         NaT            97  ...   :0:11:59:24
# 4               3Gold 2011-12-06         NaT            97  ...   :0:11:59:24
# ...               ...        ...         ...           ...  ...           ...
# 273317      2Platinum 2019-12-04         NaT             1  ...   :0:14:52:43
# 273318      2Platinum 2019-12-04         NaT             1  ...   :0:14:52:43
# 273319      2Platinum 2019-12-04         NaT             1  ...   :0:14:52:43
# 273320      2Platinum 2019-12-04         NaT             1  ...   :0:14:53:30
# 273321      2Platinum 2019-12-04         NaT             1  ...   :0:14:53:30
#
#        supply_date    item_id item_g_l item_g_m item_g_s  \
# 0       2018-01-10  P08010117       간식       과자       스낵
# 1       2018-01-10  P09040101    양념/가루        장       간장
# 2       2018-01-10  P09040100    양념/가루        장       간장
# 3       2018-10-08  P09010305    양념/가루       가루     곡식가루
# 4       2018-10-08  P09010301    양념/가루       가루     곡식가루
# ...            ...        ...      ...      ...      ...
# 273317  2019-12-22  P01010104       주곡       멥쌀       백미
# 273318  2019-12-22  P08010301       간식       과자    한과/유과
# 273319  2019-12-22  P06040300      축산물      유제품    아이스크림
# 273320  2019-12-29  P08040137       간식        빵        빵
# 273321  2019-12-29  P06030202      축산물      육가공     돼지가공
#
#                     item_name purchase_cnt unit_cost purchase_amt
# 0            꼬마찹쌀모나카(112g/8개)            1      3000         3000
# 1              제주전통어간장(500ml)            1      7900         7900
# 2                  맛간장(900ml)            1     13600        13600
# 3               엿기름가루(무/500g)            2      3200         6400
# 4                  메주가루(500g)            2     11000        22000
# ...                       ...          ...       ...          ...
# 273317          백미/유(4kg)-매장용            1     15700        15700
# 273318        차례상약과(350g/10개)            1      8800         8800
# 273319          유기농아이스크림(기본형)            1      8900         8900
# 273320  쌀로만든잉글리쉬머핀(66g×4개)/매장            1      3900         3900
# 273321         ★김밥용햄(285g)-매장            1      4500         4500
#
# [273322 rows x 36 columns]

# %%
cols = ['customer_id','purchase_amt']
x_merge_df = merge_df[cols]

sc = StandardScaler()
x_merge_df_scaled = sc.fit_transform(x_merge_df)

# %%
wcss = []

for i in range(1, 12):
    
    kmeans = KMeans(n_clusters = i, 
                    init       = 'k-means++', 
                    max_iter   = 300, 
                    n_init     = 10, 
                    random_state = 0)
    
    kmeans.fit(x_merge_df_scaled)
    
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 12), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

# %%
x_merge_df = merge_df[cols]
x_merge_df_scaled = sc.fit_transform(x_merge_df)

# %%
kmeans = KMeans(n_clusters = 4,  # optimum cluster
                    init       = 'k-means++', 
                    max_iter   = 300, 
                    n_init     = 10, 
                    random_state = 0)

y_pred = kmeans.fit_predict(x_merge_df_scaled)

# %%
merge_df['customer_id'] = y_pred
y_pred_train = kmeans.fit_predict(x_merge_df_scaled)
merge_df['customer_id'] = y_pred_train

# %%
merge_df['customer_id'].unique()
merge_df['customer_id'].value_counts()
# Out:
# 0    206355
# 2     65691
# 3      1274
# 1         2
# Name: customer_id, dtype: int64
